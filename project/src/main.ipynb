# %%
#@title Imports for env, agent, and visualisation.
# Environment
# !pip install highway-env
import gymnasium as gym
import highway_env

# Agent
# !pip install git+https://github.com/eleurent/rl-agents#egg=rl-agents
from rl_agents.agents.common.factory import agent_factory

# Visualisation
import sys
# %pip install tqdm
from tqdm.notebook import trange
# !pip install moviepy -U
# !pip install imageio_ffmpeg
# !pip install pyvirtualdisplay
# !apt-get install -y xvfb ffmpeg
# !git clone https://github.com/Farama-Foundation/HighwayEnv.git
sys.path.insert(0, './highway-env/scripts/')
# Out:
# Requirement already satisfied: highway-env in /opt/anaconda3/envs/245/lib/python3.9/site-packages (1.10.1)
# Requirement already satisfied: gymnasium>=1.0.0a2 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from highway-env) (1.1.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from highway-env) (0.0.4)
# Requirement already satisfied: numpy>=1.21.0 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from highway-env) (2.0.2)
# Requirement already satisfied: pygame>=2.0.2 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from highway-env) (2.6.1)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from highway-env) (3.9.4)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from highway-env) (2.2.3)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from highway-env) (1.13.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from gymnasium>=1.0.0a2->highway-env) (3.1.1)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from gymnasium>=1.0.0a2->highway-env) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from gymnasium>=1.0.0a2->highway-env) (4.13.2)
# Requirement already satisfied: zipp>=3.20 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from importlib-metadata>=4.8.0->gymnasium>=1.0.0a2->highway-env) (3.22.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from matplotlib->highway-env) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from matplotlib->highway-env) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from matplotlib->highway-env) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from matplotlib->highway-env) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from matplotlib->highway-env) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from matplotlib->highway-env) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from matplotlib->highway-env) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from matplotlib->highway-env) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from matplotlib->highway-env) (6.5.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->highway-env) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from pandas->highway-env) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from pandas->highway-env) (2025.2)
# Collecting rl-agents
#   Cloning https://github.com/eleurent/rl-agents to /private/var/folders/v9/sbf3kyvn34z8_7d_83by5fsw0000gn/T/pip-install-_jdb53pp/rl-agents_49f30ec36da84a1da78e39ffa564f947
#   Running command git clone --filter=blob:none --quiet https://github.com/eleurent/rl-agents /private/var/folders/v9/sbf3kyvn34z8_7d_83by5fsw0000gn/T/pip-install-_jdb53pp/rl-agents_49f30ec36da84a1da78e39ffa564f947
#   Resolved https://github.com/eleurent/rl-agents to commit 84df15ea977271e6a4d015f10f9f355f7e866890
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gymnasium in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from rl-agents) (1.1.1)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from rl-agents) (2.0.2)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from rl-agents) (2.2.3)
# Requirement already satisfied: numba in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from rl-agents) (0.60.0)
# Requirement already satisfied: pygame in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from rl-agents) (2.6.1)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from rl-agents) (3.9.4)
# Requirement already satisfied: seaborn in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from rl-agents) (0.13.2)
# Requirement already satisfied: six in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from rl-agents) (1.17.0)
# Requirement already satisfied: docopt in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from rl-agents) (0.6.2)
# Requirement already satisfied: torch>=1.2.0 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from rl-agents) (2.7.0)
# Requirement already satisfied: tensorboardX in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from rl-agents) (2.6.2.2)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from rl-agents) (1.13.1)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from torch>=1.2.0->rl-agents) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from torch>=1.2.0->rl-agents) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from torch>=1.2.0->rl-agents) (1.14.0)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from torch>=1.2.0->rl-agents) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from torch>=1.2.0->rl-agents) (3.1.6)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from torch>=1.2.0->rl-agents) (2025.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from sympy>=1.13.3->torch>=1.2.0->rl-agents) (1.3.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from gymnasium->rl-agents) (3.1.1)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from gymnasium->rl-agents) (8.7.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from gymnasium->rl-agents) (0.0.4)
# Requirement already satisfied: zipp>=3.20 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from importlib-metadata>=4.8.0->gymnasium->rl-agents) (3.22.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from jinja2->torch>=1.2.0->rl-agents) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from matplotlib->rl-agents) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from matplotlib->rl-agents) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from matplotlib->rl-agents) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from matplotlib->rl-agents) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from matplotlib->rl-agents) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from matplotlib->rl-agents) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from matplotlib->rl-agents) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from matplotlib->rl-agents) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from matplotlib->rl-agents) (6.5.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from numba->rl-agents) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from pandas->rl-agents) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from pandas->rl-agents) (2025.2)
# Requirement already satisfied: protobuf>=3.20 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from tensorboardX->rl-agents) (6.31.1)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/245/lib/python3.9/site-packages (4.67.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: moviepy in /opt/anaconda3/envs/245/lib/python3.9/site-packages (2.2.1)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from moviepy) (5.2.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from moviepy) (2.37.0)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from moviepy) (0.6.0)
# Requirement already satisfied: numpy>=1.25.0 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from moviepy) (2.0.2)
# Requirement already satisfied: proglog<=1.0.0 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from moviepy) (0.1.12)
# Requirement already satisfied: python-dotenv>=0.10 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from moviepy) (1.1.0)
# Requirement already satisfied: pillow<12.0,>=9.2.0 in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from moviepy) (11.2.1)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/245/lib/python3.9/site-packages (from proglog<=1.0.0->moviepy) (4.67.1)
# Requirement already satisfied: imageio_ffmpeg in /opt/anaconda3/envs/245/lib/python3.9/site-packages (0.6.0)
# Requirement already satisfied: pyvirtualdisplay in /opt/anaconda3/envs/245/lib/python3.9/site-packages (3.0)
# zsh:1: command not found: apt-get
# fatal: destination path 'HighwayEnv' already exists and is not an empty directory.

# %%
# from utils import record_videos, show_videos
from HighwayEnv.scripts.utils import record_videos, show_videos
# Out:
# process exited early. stderr:b"_XSERVTransmkdir: ERROR: euid != 0,directory /tmp/.X11-unix will not be created.\n_XSERVTransSocketUNIXCreateListener: mkdir(/tmp/.X11-unix) failed, errno = 2\n_XSERVTransMakeAllCOTSServerListeners: failed to create listener for local\n(EE) \nFatal server error:\n(EE) Cannot establish any listening sockets - Make sure an X server isn't already running(EE) \n"
# start failed 1
# process exited early. stderr:b"_XSERVTransmkdir: ERROR: euid != 0,directory /tmp/.X11-unix will not be created.\n_XSERVTransSocketUNIXCreateListener: mkdir(/tmp/.X11-unix) failed, errno = 2\n_XSERVTransMakeAllCOTSServerListeners: failed to create listener for local\n(EE) \nFatal server error:\n(EE) Cannot establish any listening sockets - Make sure an X server isn't already running(EE) \n"
# start failed 2
# process exited early. stderr:b"_XSERVTransmkdir: ERROR: euid != 0,directory /tmp/.X11-unix will not be created.\n_XSERVTransSocketUNIXCreateListener: mkdir(/tmp/.X11-unix) failed, errno = 2\n_XSERVTransMakeAllCOTSServerListeners: failed to create listener for local\n(EE) \nFatal server error:\n(EE) Cannot establish any listening sockets - Make sure an X server isn't already running(EE) \n"
# start failed 3
# process exited early. stderr:b"_XSERVTransmkdir: ERROR: euid != 0,directory /tmp/.X11-unix will not be created.\n_XSERVTransSocketUNIXCreateListener: mkdir(/tmp/.X11-unix) failed, errno = 2\n_XSERVTransMakeAllCOTSServerListeners: failed to create listener for local\n(EE) \nFatal server error:\n(EE) Cannot establish any listening sockets - Make sure an X server isn't already running(EE) \n"
# start failed 4
# process exited early. stderr:b"_XSERVTransmkdir: ERROR: euid != 0,directory /tmp/.X11-unix will not be created.\n_XSERVTransSocketUNIXCreateListener: mkdir(/tmp/.X11-unix) failed, errno = 2\n_XSERVTransMakeAllCOTSServerListeners: failed to create listener for local\n(EE) \nFatal server error:\n(EE) Cannot establish any listening sockets - Make sure an X server isn't already running(EE) \n"
# start failed 5
# process exited early. stderr:b"_XSERVTransmkdir: ERROR: euid != 0,directory /tmp/.X11-unix will not be created.\n_XSERVTransSocketUNIXCreateListener: mkdir(/tmp/.X11-unix) failed, errno = 2\n_XSERVTransMakeAllCOTSServerListeners: failed to create listener for local\n(EE) \nFatal server error:\n(EE) Cannot establish any listening sockets - Make sure an X server isn't already running(EE) \n"
# start failed 6
# process exited early. stderr:b"_XSERVTransmkdir: ERROR: euid != 0,directory /tmp/.X11-unix will not be created.\n_XSERVTransSocketUNIXCreateListener: mkdir(/tmp/.X11-unix) failed, errno = 2\n_XSERVTransMakeAllCOTSServerListeners: failed to create listener for local\n(EE) \nFatal server error:\n(EE) Cannot establish any listening sockets - Make sure an X server isn't already running(EE) \n"
# start failed 7
# process exited early. stderr:b"_XSERVTransmkdir: ERROR: euid != 0,directory /tmp/.X11-unix will not be created.\n_XSERVTransSocketUNIXCreateListener: mkdir(/tmp/.X11-unix) failed, errno = 2\n_XSERVTransMakeAllCOTSServerListeners: failed to create listener for local\n(EE) \nFatal server error:\n(EE) Cannot establish any listening sockets - Make sure an X server isn't already running(EE) \n"
# start failed 8
# process exited early. stderr:b"_XSERVTransmkdir: ERROR: euid != 0,directory /tmp/.X11-unix will not be created.\n_XSERVTransSocketUNIXCreateListener: mkdir(/tmp/.X11-unix) failed, errno = 2\n_XSERVTransMakeAllCOTSServerListeners: failed to create listener for local\n(EE) \nFatal server error:\n(EE) Cannot establish any listening sockets - Make sure an X server isn't already running(EE) \n"
# start failed 9
# process exited early. stderr:b"_XSERVTransmkdir: ERROR: euid != 0,directory /tmp/.X11-unix will not be created.\n_XSERVTransSocketUNIXCreateListener: mkdir(/tmp/.X11-unix) failed, errno = 2\n_XSERVTransMakeAllCOTSServerListeners: failed to create listener for local\n(EE) \nFatal server error:\n(EE) Cannot establish any listening sockets - Make sure an X server isn't already running(EE) \n"
# start failed 10
# ---------------------------------------------------------------------------
# XStartError                               Traceback (most recent call last)
# File /opt/anaconda3/envs/245/lib/python3.9/site-packages/pyvirtualdisplay/abstractdisplay.py:155, in AbstractDisplay.start(self)
#     154 try:
# --> 155     self._start1()
#     156     break
#
# File /opt/anaconda3/envs/245/lib/python3.9/site-packages/pyvirtualdisplay/abstractdisplay.py:286, in AbstractDisplay._start1(self)
#     285     msg = "Failed to start process: %s"
# --> 286     raise XStartError(msg % self)
#     287 if not ok:
#
# XStartError: Failed to start process: <pyvirtualdisplay.xvfb.XvfbDisplay object at 0x1039615b0>
#
# During handling of the above exception, another exception occurred:
#
# XStartError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 # from utils import record_videos, show_videos
# ----> 2 from HighwayEnv.scripts.utils import record_videos, show_videos
#
# File ~/Project/EE245_Robot/project/src/HighwayEnv/scripts/utils.py:10
#       6 from pyvirtualdisplay import Display
#       9 display = Display(visible=0, size=(1400, 900))
# ---> 10 display.start()
#      13 def record_videos(env, video_folder="videos"):
#      14     wrapped = RecordVideo(
#      15         env, video_folder=video_folder, episode_trigger=lambda e: True
#      16     )
#
# File /opt/anaconda3/envs/245/lib/python3.9/site-packages/pyvirtualdisplay/display.py:72, in Display.start(self)
#      66 def start(self) -> "Display":
#      67     """
#      68     start display
#      69
#      70     :rtype: self
#      71     """
# ---> 72     self._obj.start()
#      73     return self
#
# File /opt/anaconda3/envs/245/lib/python3.9/site-packages/pyvirtualdisplay/abstractdisplay.py:162, in AbstractDisplay.start(self)
#     160             i += 1
#     161             if i >= self._retries:
# --> 162                 raise XStartError(
#     163                     "No success after %s retries. Last stderr: %s"
#     164                     % (self._retries, self.stderr)
#     165                 )
#     166 if self._manage_global_env:
#     167     self._redirect_display(True)
#
# XStartError: No success after 10 retries. Last stderr: b"_XSERVTransmkdir: ERROR: euid != 0,directory /tmp/.X11-unix will not be created.\n_XSERVTransSocketUNIXCreateListener: mkdir(/tmp/.X11-unix) failed, errno = 2\n_XSERVTransMakeAllCOTSServerListeners: failed to create listener for local\n(EE) \nFatal server error:\n(EE) Cannot establish any listening sockets - Make sure an X server isn't already running(EE) \n"

# %%
#@title Run an episode

# Make environment
env = gym.make("highway-fast-v0", render_mode="rgb_array")
env = record_videos(env)
(obs, info), done = env.reset(), False

# Make agent
agent_config = {
    "__class__": "<class 'rl_agents.agents.tree_search.deterministic.DeterministicPlannerAgent'>",
    "env_preprocessors": [{"method":"simplify"}],
    "budget": 50,
    "gamma": 0.7,
}
agent = agent_factory(env, agent_config)

# Run episode
for step in trange(env.unwrapped.config["duration"], desc="Running..."):
    action = agent.act(obs)
    obs, reward, done, truncated, info = env.step(action)
    
env.close()
show_videos()
